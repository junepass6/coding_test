# %%
x, y = 1, 1
print(x, y)
# Out:
# 1 1

# %%
plans = input().split() #공백을 기준으로 나눠서 리스트로 만들어준다.
plans
# Out:
# ['3', '5']

# %%
n = int(input())
x, y = 1, 1
plans = input().split() #공백을 기준으로 문자열을 나눠서 리스트로 만들어준다.

dx = [0, 0, -1, 1]
dy = [-1, 1, 0, 0]
move_types = ['L', 'R', 'U', 'D']

for plan in plans:
    print(plan)
    print('*******')
    for i in range(len(move_types)):
        print(i)
        if plan == move_types[i]:
            nx = x + dx[i]
            ny = y + dy[i]
            
    if nx < 1 or ny <1 or nx > n or ny > n:
        continue
    x, y = nx, ny
    
print(x,y)
# Out:
# R
# *******
# 0
# 1
# 2
# 3
# R
# *******
# 0
# 1
# 2
# 3
# R
# *******
# 0
# 1
# 2
# 3
# U
# *******
# 0
# 1
# 2
# 3
# D
# *******
# 0
# 1
# 2
# 3
# D
# *******
# 0
# 1
# 2
# 3
# 3 4

# %%
input_data = input()
row = input_data[1]
print('~~~~', row)

column = int(ord(input_data[0])) - int(ord('a')) + 1
print(ord(input_data[0]))
print(int(ord('a')))
print(column)
# Out:
# ~~~~ 2
# 98
# 97
# 2

# %%
input_data = input()
row = int(input_data[1])

#ord('a'): 특정한 한 문자를 아스키 코드 값(=숫자형태)으로 변환해 주는 함수 
#a -> 97, b -> 98, c -> 99
column = int(ord(input_data[0])) - int(ord('a')) + 1

steps = [(-2, -1), (-2, 1), (2, -1), (2, 1), (1, 2), (1, -2), (-1, 2), (-1, -2)]

count = 0
for step in steps:
    next_row = row + step[0]
    next_col = column + step[1]
    if next_row >= 1 and next_row <= 8 and  next_col >= 1 and next_col <= 8:
        count += 1

print(count)
# Out:
# 2

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
h = int(input())

count = 0
for i in range(h+1):
    for j in range(60):
        for k in range(60):
            print(str(i) + str(j) + str(k))
            print(type(str(i) + str(j) + str(k)))
            if '3' in str(i) + str(j) + str(k):
                count += 1

print(count)
# Out:
# 000
# <class 'str'>
# 001
# <class 'str'>
# 002
# <class 'str'>
# 003
# <class 'str'>
# 004
# <class 'str'>
# 005
# <class 'str'>
# 006
# <class 'str'>
# 007
# <class 'str'>
# 008
# <class 'str'>
# 009
# <class 'str'>
# 0010
# <class 'str'>
# 0011
# <class 'str'>
# 0012
# <class 'str'>
# 0013
# <class 'str'>
# 0014
# <class 'str'>
# 0015
# <class 'str'>
# 0016
# <class 'str'>
# 0017
# <class 'str'>
# 0018
# <class 'str'>
# 0019
# <class 'str'>
# 0020
# <class 'str'>
# 0021
# <class 'str'>
# 0022
# <class 'str'>
# 0023
# <class 'str'>
# 0024
# <class 'str'>
# 0025
# <class 'str'>
# 0026
# <class 'str'>
# 0027
# <class 'str'>
# 0028
# <class 'str'>
# 0029
# <class 'str'>
# 0030
# <class 'str'>
# 0031
# <class 'str'>
# 0032
# <class 'str'>
# 0033
# <class 'str'>
# 0034
# <class 'str'>
# 0035
# <class 'str'>
# 0036
# <class 'str'>
# 0037
# <class 'str'>
# 0038
# <class 'str'>
# 0039
# <class 'str'>
# 0040
# <class 'str'>
# 0041
# <class 'str'>
# 0042
# <class 'str'>
# 0043
# ...
